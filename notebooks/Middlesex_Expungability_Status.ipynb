# %%
import pandas as pd

ms_df = pd.read_csv("data/cleaned/clean_middlesex.csv")
ms_df.head()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     Case Number Offense Date Court Location  \
# 0  14-01-479818   2013-12-30            SOM
# 1  14-01-479826   2013-12-29            LOW
# 2  14-01-479854   2013-12-31            SOM
# 3  14-01-479887   2013-12-28            AYE
# 4  14-01-479888   2013-05-19            CON
#
#                                    Charge  \
# 0  LICENSE SUSPENDED, OP MV WITH c90 Â§23
# 1  LICENSE SUSPENDED, OP MV WITH c90 Â§23
# 2  LICENSE SUSPENDED, OP MV WITH c90 Â§23
# 3  LICENSE SUSPENDED, OP MV WITH c90 Â§23
# 4  LICENSE SUSPENDED, OP MV WITH c90 Â§23
#
#                            Charge/Crime Type               Disposition  \
# 0  Drugs/Distribution/Possession with Intent              GUILTY FILED
# ...

# %%
conditions = ms_df['Expungeable'].unique().tolist()
print(conditions)
# Out:
# ['Yes', 'No', 'Attempt', nan, 'm']

# %%
unknwn_conditions = conditions[2:]

unknwn_expung_stat = pd.DataFrame()
for unkwn in unknwn_conditions:
    ms_df[ms_df['Expungeable'] == unkwn]
