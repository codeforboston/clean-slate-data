# %% [markdown]
# # Clean Slate: Estimating offenses eligible for expungement under varying conditions
# > Prepared by [Laura Feeney](https://github.com/laurafeeney) for Code for Boston's [Clean Slate project](https://github.com/codeforboston/clean-slate).
#
# ## Purpose & Notes
# Clean and merge Middlesex DA data with expungement eligibility data.
# This data was sourced from the Middlesex DA website: https://www.middlesexda.com/public-information/pages/prosecution-data-and-statistics
#
# Description from website: "The following is data from our Damion Case Management System pertaining to prosecution statistics for the time period from January 1, 2014, through January 1, 2020."
#
# The download is available as an Excel file. Opening excel in Python was too slow, so I manually converted it to csv, and imported via csv.
#
# Note: This did not have age or DOB.
#
# The Middlesex DA site says this should be prosecutions for 2014 - 2019. However, not all offense dates nor all disposition dates are within this timeline.
#
# ### Merging
# The Charges have a slightly different format, character set, and phrasing of charges than the Suffolk and NW data, which we obtained first. Will need some manual updating to get expungment info for all charges.
#
# ### Still to do
# * clean up sex and murder columns -- needs to be filled in for the unmatched from PCD / MCL / extra info.
#
# -----

# %%
import pandas as pd
pd.set_option("display.max_rows", 200)
import numpy as np
import regex as re
import glob, os
import datetime 
from datetime import date 

#print(os.getcwd())
os.chdir("../../data/raw")
#print(os.getcwd())

# %%
#ms_raw = pd.read_excel('damion_database_2014-2019_6.30.xlsx') # too slow to do this way
ms_raw = pd.read_csv('damion_database_2014-2019_6.30.csv') 
columns = ['Case Number', 'Offense Date', 'Date of Filing', 'Court Location', 
           'Charge/Crime Code', 'Charge/Crime Description', 'Charge/Crime Type',
           'Disposition Description', 'Disposition Date']
ms = ms_raw[columns].replace()
ms.head()
# Out:
#     Case Number Offense Date Date of Filing Court Location Charge/Crime Code  \
# 0  14-01-479818   12/30/2013       1/2/2014            SOM           90/23/D
# 1  14-01-479818   12/30/2013       1/2/2014            SOM         94C/32C/C
# 2  14-01-479819   12/31/2013       1/2/2014            SOM          94C/34/C
# 3  14-01-479819   12/31/2013       1/2/2014            SOM           90/17/A
# 4  14-01-479819   12/31/2013       1/2/2014            SOM             89/4A
#
#                         Charge/Crime Description  \
# 0          LICENSE SUSPENDED, OP MV WITH c90 §23
# 1  DRUG, POSSESS TO DISTRIB CLASS D c94C §32C(a)
# 2                 DRUG, POSSESS CLASS B c94C §34
# 3                             SPEEDING * c90 §17
# 4               MARKED LANES VIOLATION * c89 §4A
#
#                            Charge/Crime Type   Disposition Description  \
# 0  Drugs/Distribution/Possession with Intent              GUILTY FILED
# 1  Drugs/Distribution/Possession with Intent            NOLLE PROSEQUI
# 2                           Drugs/Possession  DISMISSED W/O  PREJUDICE
# 3                           Drugs/Possession               RESPONSIBLE
# 4                           Drugs/Possession               RESPONSIBLE
#
#   Disposition Date
# 0         6/2/2014
# 1         6/2/2014
# 2         5/9/2014
# 3         5/9/2014
# 4         5/9/2014

# %% [markdown]
# ### Cleaning and variable prep

# %%
ms.rename(columns={"Charge/Crime Description":"Charge"}, inplace=True)

# Label CMR offenses (Code of Mass Regulations)
ms['CMRoffense'] = False
ms.loc[ms['Charge'].str.contains("CMR"), 'CMRoffense'] = True

#Extract Chapter, Section, and Paragrah (I think the third one would be paragraph? It isn't always populated)
chsec = ms['Charge/Crime Code'].str.split("/", n = 2, expand = True) 
ms['Chapter'] = chsec[0]
ms['Section'] = chsec[1]
ms['Paragraph'] = chsec[2]

# Remove weird A character, and create a version with no spaces and no extra characters. This file has different spacing 
# than NW and Suffolk or Master Crime List descriptions.

ms['Charge_noA'] = ms['Charge'].map(lambda x: x.replace('Â',""))
ms['Charge_alnum'] = ms['Charge_noA'].str.replace(r'\W+', '', )
ms['Charge_alnum2'] = ms['Charge_alnum'].str.replace("[^a-zA-Z0-9 -]","",)

# Proxy for age -- using a juvenile court
ms['JuvenileC'] =  False
ms.loc[ms['Court Location'].str.contains("JU"), 'JuvenileC'] = True

# %% [markdown]
# ### dates. Supposed to be 2014-2019

# %%
reference_date = datetime.date(2020, 9, 1) # using "today.date() wouldn't be stable"

ms['Offense Date'] = pd.to_datetime(ms['Offense Date'], errors='coerce').dt.date
import math
ms['years_since_offense'] = (reference_date - ms['Offense Date'])/pd.Timedelta(1, 'D')/365

ms['years_since_offense'] = ms['years_since_offense'].fillna(999).astype(int)
ms['years_since_offense'].loc[ms['years_since_offense']<999].describe()
# Out:
# count    343072.000000
# mean          3.760619
# std           2.443959
# min           0.000000
# 25%           2.000000
# 50%           4.000000
# 75%           5.000000
# max          69.000000
# Name: years_since_offense, dtype: float64

# %%
print("The earliest offense date is:    ", min(ms['Offense Date']))
print("The max offense date is:         ", max(ms['Offense Date']), "\n")

print("Distribution of years since offense:", "\n", ms['years_since_offense'].describe(), "\n")

before_2013 = ms['Case Number'][ms['Offense Date']<datetime.date(2013,1,1)].nunique()
before_2014 = ms['Case Number'][ms['Offense Date']<datetime.date(2014,1,1)].nunique()
after_2014 = ms['Case Number'][ms['Offense Date']>=datetime.date(2014,1,1)].nunique()
after_2013 = ms['Case Number'][ms['Offense Date']>=datetime.date(2013,1,1)].nunique()


print("There are", before_2014, "cases with offense date prior to Jan 1, 2014",
     "and", before_2013, "cases before 2013")

print("Percent of cases before 2014:",round(before_2014*100/after_2014,2), "\n"
     "Percent before 2013:", round(before_2013*100/after_2013,2))
# Out:
# The earliest offense date is:     1951-06-30
# The max offense date is:          2019-12-30
#
# Distribution of years since offense:
#  count    343099.000000
# mean          3.838939
# std           9.160435
# min           0.000000
# 25%           2.000000
# 50%           4.000000
# 75%           5.000000
# max         999.000000
# Name: years_since_offense, dtype: float64
#
# There are 9965 cases with offense date prior to Jan 1, 2014 and 2963 cases before 2013
# Percent of cases before 2014: 6.48
# Percent before 2013: 1.84

# %%
#ms.to_csv('../../data/raw/ms.csv', index=False)

# msc -- Charges with value counts

msc = ms['Charge'].value_counts().rename_axis('Charge').reset_index(name='Nvalues')
msc['Charge_noA'] = msc['Charge'].map(lambda x: x.replace('Â',""))
msc['Charge_alnum'] = msc['Charge_noA'].str.replace(r'\W+', '', )

# %% [markdown]
# ### Datasets with expungement info
# These were created from the Suffolk and NW data, in for example [MA_Data-1_Raw.ipynb](https://github.com/codeforboston/clean-slate/blob/master/analyses/notebooks/MA_Data-1_Raw.ipynb).
# This follows a similar process as [MA_Data-2_MergeCharges_alt.ipynb](https://github.com/codeforboston/clean-slate/blob/master/analyses/notebooks/MA_Data-2_MergeCharges_alt.ipynb).
#
# Prosecution charges detailed is the result of matching the NW and Suffolk charges with each other, and then matching that with the [Master Crime List](https://drive.google.com/file/d/11iD3ilejUW28NE6DdUaUkkp3PoPauhCj/view?usp=sharing), then manually filling in missing expungeabiliyt information, and rationalizing duplicate rows. Duplicate rows occurred because within a chapter and section, some charges may be expungeable while others may not.

# %%
#read in procesuction charges detailed file

PCD = pd.read_csv('../../data/processed/prosecution_charges_detailed.csv', encoding='cp1252') 
PCD.rename(columns={"Expungeable.":"Expungeable"}, inplace=True)
columns = ['Charge', 'Chapter', 'Section', 'Expungeable', 'sex', 'murder', 'extra_criteria']
PCD = PCD[columns]
PCD['Charge_noA'] = PCD['Charge'].map(lambda x: x.replace('Â',""))

PCD['Charge_alnum'] = PCD['Charge_noA'].str.replace(r'\W+', '', )
#PCD.info()

#read in additional info that fills in blanks from PCD. This was manually done by cross-referncing with MCL
# Then we confirmed  with Sana for things that weren't obvious. 

addtl_exp = pd.read_csv('../../data/raw/missing_expungeability_08-02.csv', encoding='cp1252') 
addtl_exp.rename(columns={"Expungeable.":"Expungeable"}, inplace=True)
columns = ['Charge', 'Expungeable', 
           'Reason not expungeable', 'Analysis notes']
addtl_exp = addtl_exp[columns]
addtl_exp['Expungeable'].replace({'yes': 'Yes', 'no': 'No', 'na': 'NA--CMR'}, inplace=True)


# merge these two expungement info datasets

exp = PCD.merge(addtl_exp, on='Charge', how='left')

def replace_values_merge(df, new, x, y):
    df[new] = df[x]
    df[new].fillna(df[y], inplace=True)
    df.drop([x,y], axis=1, inplace=True)
    #print(df[new].value_counts(dropna=False))
    
replace_values_merge(exp, "Expungeable", "Expungeable_x", "Expungeable_y")

exp['CMRoffense'] = False
exp.loc[exp['Charge'].str.contains("CMR"), 'CMRoffense'] = True

exp.loc[(exp['Expungeable'] == "Yes") & (exp['CMRoffense'] == True), ['Expungeable']] = "NotApplicable"

exp.loc[(exp['Charge'] == "BURGLARY, UNARMED & ASSAULT c266 Â§14"),['Expungeable']] = "No" # not expungealbe
exp.loc[(exp['Charge'] == "ATTEMPT TO COMMIT CRIME c274 Â§6"),['Expungeable']] = "Attempt" # need more info 
exp.loc[(exp['Charge'] == "ATTEMPT TO COMMIT CRIME, HABITUAL c274 Â§6"),['Expungeable']] = "Attempt" # need more info 

exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1650 entries, 0 to 1649
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Charge                  1650 non-null   object
#  1   Chapter                 1555 non-null   object
#  2   Section                 1562 non-null   object
#  3   sex                     1650 non-null   int64
#  4   murder                  1650 non-null   int64
#  5   extra_criteria          41 non-null     object
#  6   Charge_noA              1650 non-null   object
#  7   Charge_alnum            1650 non-null   object
#  8   Reason not expungeable  437 non-null    object
#  9   Analysis notes          7 non-null      object
#  10  Expungeable             1650 non-null   object
#  11  CMRoffense              1650 non-null   bool
# dtypes: bool(1), int64(2), object(9)
# memory usage: 156.3+ KB

# %%
# Merge data on expungement. Unique offenses. 

ms_merged = msc.merge(exp, on='Charge_alnum', how='left', indicator = True)
print(ms_merged._merge.value_counts())

ms_merged['unmatched'] = ms_merged['_merge']=="left_only"

replace_values_merge(ms_merged, "Charge", "Charge_x", "Charge_y")

ms_merged = ms_merged.drop(columns = ['Charge_noA_x', 'Charge_noA_y',
                                      '_merge'])
ms_merged.info()
# Out:
# both          921
# left_only     336
# right_only      0
# Name: _merge, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1257 entries, 0 to 1256
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nvalues                 1257 non-null   int64
#  1   Charge_alnum            1257 non-null   object
#  2   Chapter                 903 non-null    object
#  3   Section                 903 non-null    object
#  4   sex                     921 non-null    float64
#  5   murder                  921 non-null    float64
#  6   extra_criteria          27 non-null     object
#  7   Reason not expungeable  227 non-null    object
#  8   Analysis notes          2 non-null      object
#  9   Expungeable             921 non-null    object
#  10  CMRoffense              921 non-null    object
#  11  unmatched               1257 non-null   bool
#  12  Charge                  1257 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(9)
# memory usage: 128.9+ KB

# %%
#indicate CMRs
ms_merged.loc[ms_merged['Charge'].str.contains("CMR"), 'CMRoffense'] = 'yes'
ms_merged.CMRoffense.fillna("no", inplace=True)

ms_merged.loc[ms_merged['CMRoffense'] == "yes", ['Expungeable']] = "NA - CMR"

#drop unneeded columns and save list of charges without expungement info
columns = ['Charge', 'Charge_alnum', 'Nvalues', 'Chapter', 'Section', 
           'Expungeable', 'CMRoffense', 'unmatched']

ms_unmatched = ms_merged[columns].loc[ (ms_merged['unmatched']==True) & 
                                      ms_merged['Expungeable'].isnull()]

#ms_unmatched.to_csv('../../data/raw/unmatched_middlesex_to_clean.csv', index=True)

ms_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1257 entries, 0 to 1256
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nvalues                 1257 non-null   int64
#  1   Charge_alnum            1257 non-null   object
#  2   Chapter                 903 non-null    object
#  3   Section                 903 non-null    object
#  4   sex                     921 non-null    float64
#  5   murder                  921 non-null    float64
#  6   extra_criteria          27 non-null     object
#  7   Reason not expungeable  227 non-null    object
#  8   Analysis notes          2 non-null      object
#  9   Expungeable             932 non-null    object
#  10  CMRoffense              1257 non-null   object
#  11  unmatched               1257 non-null   bool
#  12  Charge                  1257 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(9)
# memory usage: 128.9+ KB

# %% [markdown]
# Data exported to csv, saved in the google drive, and farmed out to the team to compare against the Master Crime List to fill in missing expungement information.

# %%
ms_new_data = pd.read_csv('../../data/raw/unmatched_middlesex_clean.csv')

# %%
ms_new_data['Charge_alnum2'] = ms_new_data['Charge_alnum'].str.replace("[^a-zA-Z0-9 -]","",)
ms_new_data = ms_new_data.drop(columns = ['Charge', "Charge_alnum", 'Nvalues', 'Group #', 'Name of updater', 'Index'])

ms_merged['Charge_alnum2'] = ms_merged['Charge_alnum'].str.replace("[^a-zA-Z0-9 -]","",)

ms_merged_full = ms_merged.merge(ms_new_data, on='Charge_alnum2', how='outer', indicator=True)

print(ms_merged_full._merge.value_counts(dropna=False))
ms_merged_full.drop(['_merge'], axis=1, inplace=True)
# Out:
# left_only     932
# both          325
# right_only      0
# Name: _merge, dtype: int64

# %%
replace_values_merge(ms_merged_full, "Expungeable", "Expungeable_x", "Expungeable_y")
replace_values_merge(ms_merged_full, "Reason not expungeable", "Reason not expungeable_x", "Reason not expungeable_y")

ms_merged_full = ms_merged_full.drop(columns = ['Charge', "Charge_alnum", 'Chapter', 'Section', 'Nvalues', 'CMRoffense'])

# %%
ms_merged_charges = ms.merge(ms_merged_full, on='Charge_alnum2', how='outer', indicator=True)
print(ms_merged_charges['_merge'].value_counts())
ms_merged_charges.drop(['_merge'], axis=1, inplace=True)
# Out:
# both          392605
# right_only         0
# left_only          0
# Name: _merge, dtype: int64

# %% [markdown]
# ### Sex offenses
#
# Some work by Joel: https://colab.research.google.com/drive/1t4WjF6RRSWrf5vtO5WMx4YiBHRRgO6e9#scrollTo=G577BSuLeTjY
# Reviewed 'false negatives': many are still not sex offenses as per 100J.
#
# **not sex offenses**
#
# 'NIGHTWALKER, COMMON c272 §53',
# 'STREETWALKER, COMMON c272 §53',
# 'PROSTITUTION, KEEP HOUSE OF c272 §24',
# 'BESTIALITY c272 §34', # rule says "engaging in sexual contact with an animal under" c272 s77c, but does not list section 34
# 'SODOMY c272 §34',
# 'UNNATURAL ACT c272 §35', # rule lists 35A but not 35. perhaps a different "unnatural act" or minor/not minor
# 'OBSCENE MATTER, DISTRIBUTE c272 §29', #rule lists 29a but not 29
#
# **additional sex offenses identified by manual review are included in the list below in the code**

# %%
not_sex_offenses = ['NIGHTWALKER, COMMON c272 §53', 
                   'STREETWALKER, COMMON c272 §53', 
                    'PROSTITUTION, KEEP HOUSE OF c272 §24',
                    'BESTIALITY c272 §34', 
                    'SODOMY c272 §34',
                   'UNNATURAL ACT c272 §35', 
                   'OBSCENE MATTER, DISTRIBUTE c272 §29']                   

additional_sex_offenses = ['INDECENT A&B ON CHILD UNDER 14 c265 §13B',
    'PROSTITUTION, PROCURE PERSON TO PRACTICE c272 §12',
    'INDECENT A&B ON CHILD UNDER 14, SUBSQ. c265 §13B',
    'ASSAULT TO RAPE, SUBSQ.OFF. c265 §24',
    'INDECENT A&B ON +60/DISABLED c265 §13H',
    'INDECENT A&B ON CHILD UNDER 14, AGGRAVATED c265 §13B½',
    'INDECENT A&B ON PERSON 14 OR OVER SUBSQ OFFENSE OR AFTER OTHER CERTAIN OFFENSES c265 §13H',
    'INDECENT A&B ON PERSON WITH INTELLECTUAL DISABILITY c265 §13F',
    'PHOTOGRAPH SEXUAL OR INTIMATE PARTS OF CHILD  c272',
    'RAPE OF CHILD WITH FORCE, AGGRAVATED c265 §22B',
    'RAPE OF CHILD WITH FORCE, AGGRAVATED, JOINT ENTERPRISE c265 §22B',
    'RAPE OF CHILD, AGGRAVATED, FIVE YEAR AGE DIFFERENCE c265 §23A',
    'RAPE OF CHILD, AGGRAVATED, TEN YEAR AGE DIFFERENCE c265 §23A',
    'RAPE OF CHILD, STATUTORY, AFTER CERTAIN OFFENSES c265 §23B',
    'RAPE OF CHILD, STATUTORY, AGGRAVATED c265 §23A',
    'SEXUAL CONDUCT WITH CHILD UNDER 18, PAY FOR c272 §53A', #suppressing (c) to avoid an error
    'TRAFFICKING OF PERSON UNDER 18 FOR FORCED SERVICES c265 §51', #suppressing (b) to avoid an error
    'TRAFFICKING OF PERSON UNDER 18 FOR SEXUAL SERVITUDE c265 §50'] ##suppressing (b) to avoid an error

print(ms_merged_charges.sex.value_counts(dropna=False))
for x in additional_sex_offenses:
    ms_merged_charges.loc[ms_merged_charges.Charge.str.contains(x), 'sex'] = 1 
for x in not_sex_offenses:
    ms_merged_charges.loc[ms_merged_charges.Charge.str.contains(x), 'sex'] = 0                            
print(ms_merged_charges.sex.value_counts(dropna=False))
# Out:
# 0.0    357277
# NaN     32269
# 1.0      3059
# Name: sex, dtype: int64
# 0.0    356836
# NaN     31856
# 1.0      3913
# Name: sex, dtype: int64

# %%
sorted(ms_merged_charges['Charge'].loc[(ms_merged_charges['sex'].isnull()) ].unique())
# Out:
# ['A&B ATTEMPT WITH FIREARM c265 § 15F',
#  'A&B ON CHILD TO JOIN CONSPIRACY c265 §44',
#  'A&B ON CORRECTIONAL FACILITY EMPLOYEE c127 §38B(b)',
#  'A&B ON FAMILY / HOUSEHOLD MEMBER c265 §13M(a)',
#  'A&B ON FAMILY/HOUSEHOLD MEMBER SUBSEQUENT c265 §13M(b)',
#  'A&B ON PERSON WITH INTELLECTUAL DISABILITY c265 §13F',
#  'A&B WITH BODILY SUBSTANCE ON CORRECTIONAL FACILITY EMPLOYEE c127 §38B(c)',
#  'A&B WITH FIREARM c265 § 15E',
#  'A&B, SERIOUS BODILY INJURY c265 §13A(b)',
#  'ABANDONED/STOLEN MV, IMPROP REMOVE c90 §24H',
#  'AGGRAVATED ORGANIZED RETAIL CRIME OVER $10,000 c266 §30D(c)',
#  'AID CHILD TO VIOLATE JUVENILE COURT ORDER c119 §63A',
#  'ALCOHOL IN MV, POSSESS OPEN CONTAINER OF c90 §24I',
#  'AMMUNITION OF UNLAWFUL CALIBER c131 §67',
#  'AMMUNITION WITHOUT FID CARD, POSSESS c269$10 (h)(1)',
#  'AMMUNITION WITHOUT FID CARD, POSSESS, SUBSQ. OFF. c269 §10(h)(1)',
#  'ANIMAL FIGHT, PRESENCE AT c272 §95',
#  'ANIMAL INSPECTION, OBSTRUCT DFA c129 §7',
#  'ANIMAL QUARANTINE, BREAK c129 §30',
#  'ANIMAL, MALICIOUS KILLING OR INJURY TO DOMESTIC c266 §112',
#  'ANIMAL, POSSESS WITHOUT LICENSE c131 §25',
#  'ARCHEOLOGICAL VIOLATION c9 §27C',
#  'ASSAULT AND BATTERY ON A FAMILY OR HOUSEHOLD MEMBER',
#  'ASSAULT ON FAMILY / HOUSEHOLD MEMBER c265 §13M(a)',
#  'ASSAULT ON FAMILY/HOUSEHOLD MEMBER SUBSEQUENTc265 §13M(b)',
#  'ASSAULT TO MURDER +60, FIREARM-ARMED c265 §18(a)',
#  'ASSAULT TO ROB +60, FIREARM-ARMED c265 §18(a)',
#  'ASSAULT WITH HYPODERMIC c.265§15C(a)',
#  'ASSAULT, AGGRAVATED c265 §13A(b)',
#  'ASSOCIATION INSIGNIA, FALSE USE OF c266 §69',
#  'ASSOCIATION MEMBER EMBEZZLE +$250 c266 §59 & §30(1)',
#  'ATTACHING PLATES c90 §23',
#  'ATTEMPTED LARCENY BY SINGLE SCHEME c266 §30(1) & c274 § 6',
#  'ATTEMPTED LARCENY c266 §30(1) & c274 § 6',
#  'Assault w/Hypodermic Needle',
#  'B&E TO STEAL FIREARM c269 §10J(a)',
#  'BIRD OF PREY, HUNT c131 §75A',
#  'BIRTH CERTIFICATE, FORGED/ALTERED c46 §30',
#  'BOAT GROUNDED/ABANDONED c91 §49',
#  'BOAT HOMICIDE BY NEGLIGENT OP c90B §8B(2)',
#  'BOAT HOMICIDE OUI\x97LIQUOR c90B §8B(2)',
#  'BOAT, FIT OUT TO DESTROY c266 §109',
#  'BOAT, LEAVE SCENE OF PROPERTY DAMAGE BY c90B §8(e)(1)',
#  'BODY, DISINTER c272 §71',
#  'BOMB/HIJACK THREAT, FALSE c269 §14(b)',
#  'BOUNDARY MARK, VANDALIZE c266 §94',
#  'BOW & ARROW, HUNT WITH IMPROP c131 §69',
#  'BUILDING CODE VIOL W/INJURY/DEATH, WANTON/RECKLESS c148 §34B',
#  'BURGLARY, FIREARM-ARMED & ASSAULT c266 §14',
#  'BURN BOAT c266 §5',
#  'BURN PERSONALTY, ATTEMPT TO c266 §5A',
#  'BURN PUBLIC BUILDING, ATTEMPT TO c266 §5A',
#  'CAN/BOTTLE, DEFACE REGISTERED c110 §23',
#  'CARRY LOADED FIREARM WITHOUT LICENSE C269 S10 EE',
#  'CHILD ENDANGERMENT WHILE OUI c90 §24V',
#  'CHILD UNDER 8 & UNDER 58" WITHOUT CARSEAT * c90 §7AA',
#  'CIGARETTE EXCISE STAMP, COUNTERFEIT c64C §37',
#  'CITATION, DISPOSE OF UNLAWFULLY c90C §10',
#  'COCAINE, DISTRIBUTE TO MINOR c94C §32F(d)',
#  'COCAINE, TRAFFICKING IN 18 GRAMS OR MORE, LESS THAN 36 GRAMS  c94C',
#  'COCAINE, TRAFFICKING IN, 36 GRAMS OR MORE, LESS THAN 100 GRAMS c94C §32E(b)',
#  'COMMUNITY PAROLE SUPERVISION FOR LIFE c265 §45',
#  'COMPUTER SVCE, ATT FALSELY OBTAIN COMMER c266 §33A',
#  'CONSPIRACY, FIRST  c274 §7',
#  'CONSPIRACY, FOURTH MISDEMEANOR  c274 §7',
#  'CONSUME MARIJUANA IN PUBLIC PLACE c94G §13(c)',
#  'CONSUMER CONTRACT W/O CANCEL NOTICE c93 §48(B)',
#  'CORPORATE CREDIT/MONEY/PROPERTY, MISUSE c266 §74',
#  "COUNTERFEIT TRAVELLER'S CHECK, POSSESS c267 §12",
#  'COUNTY BUILDING, VANDALIZE c266 §97',
#  'CREDIT CARD, SELL/BUY c266 §37B(d)',
#  'CREDIT CARD, TAKE AS SECURITY c266 §37C(a)',
#  'DAIRY TRUCK W/O LICENSEE NAME c94 §40',
#  'DANGEROUS WEAPONS, MFR/SELL CERTAIN c269 §12',
#  'DBA CERTIFICATE VIOLATION c110 §5',
#  'DEER/WATERFOWL, HUNT WITHOUT STAMP c131 §13',
#  'DEPT OF BANK & INSUR, FALSE STATEMENT TO c268 §6',
#  'DEPT OF PUB UTILS, FALSE STATEMENT TO c268 §6',
#  'DISORDERLY CONDUCT (SUBSEQUENT OFFENSE)',
#  'DISORDERLY CONDUCT AT POLL c56 §46',
#  'DOG ORDINANCE/BY-LAW VIOLATION c140 §147A',
#  'DOG UNLEASHED AT REST AREA c140 §174B',
#  'DOG, FAIL MUZZLE/RESTRAIN c140 §168',
#  'DOG/CAT, MOTORIST FL REPORT INJURY TO * c272 §80H',
#  'DOG/DOMESTIC ANIMAL, KEEP STRAY c272 §85A',
#  'DRUG PARAPHERNALIA, SELL TO MINOR c94C §32I(b)',
#  'DRUG, DISTRIBUTE TO MINOR CLASS A c94C §32F(a)',
#  'DRUG, DISTRIBUTE TO MINOR CLASS B c94C §32F(b)',
#  'DRUG, DISTRIBUTE TO MINOR CLASS C c94C §32F(c)',
#  'DRUG, POSSESS TO DISTR TO MINOR CLASS B c94C §32F(b)',
#  'DRUG, POSSESS TO DISTR TO MINOR CLASS C c94C §32F(c)',
#  'ELDER/DISABLED, PERMIT ABUSE ON c265 §13K(d½)',
#  'ELECTION SUPERVISOR, HINDER c54 §23',
#  'ELECTRONIC ENTICEMENT OF CHILD FOR COMMERCIAL SEXUAL ACTIVITY c265 §26D(c)',
#  'ELECTRONIC ENTICEMENT OF CHILD FOR HUMAN TRAFFICKING c265 §26D(c)',
#  'ELECTRONIC FUND TRANSFER VIOL OVER $100 c167B §21(c)',
#  'ELECTRONIC FUND TRANSFER VIOL c167B §21(a)',
#  'ELECTRONIC MESSAGE, OPERATOR SEND/READ * C9',
#  'EMERGENCY VEHICLE, OBSTRUCT STATIONARY * c89 s7C',
#  'EMERGENCY, VIOLATE REGUL FOR STATE OF c23 §9H',
#  'ENGINEERING/LAND SURVEYING, UNLICENSED c112 §81T',
#  'EQUIPMENT, SELL NONCONFORM MV c90 §7',
#  'ESCAPE FROM S.D.P. TREATMENT CENTER c268 §16',
#  'EXPLOSIVES, POSSESS c266 §102(c)',
#  'EXPLOSIVES, SECRETE/THROW/LAUNCH/PLACE c266 §102A',
#  'FALSE CREATION OR USE OF SALES RECEIPT c266 §30C',
#  'FALSE/SILENT 911 CALL c269 §14B',
#  'FELONY FOR HIRE c265 §13G',
#  'FENTANYL, TRAFFICKING IN MORE THAN 10 GRAMS c.94C, §32E(c½)',
#  'FIREARM APPLIC, FALSE STATEMENT ON c140 §129',
#  'FIREARM IN FELONY, POSSESS c265 §18B',
#  'FIREARM IN FELONY, POSSESS, SUBSQ. OFF. c265 §18B',
#  'FIREARM LICENSE APPLIC, FALSE c140 §131(h)',
#  'FIREARM LICENSE/ID CARD, FALSE c140 §131I',
#  'FIREARM PURCHASE FOR ANOTHER c140 §131E',
#  'FIREARM TRANSPORT INTO COMMONWEALTH, CRIMINAL ACTIVITY c269 §10I(a)',
#  'FIREARM TRANSPORT INTO COMMONWEALTH, SELL c269 §10I(b)',
#  'FIREARM UNATTENDED c269 s.10(h)(2)',
#  'FIREARM W/DEFACED NO., POSSESS c269 §11C',
#  'FIREARM, ATTEMPTED LARCENY OF c266 §30(1) & c274 § 6',
#  'FIREARM, CARRY WITHOUT LICENSE LOADED, 2ND OFF. c269 s.10(n)',
#  'FIREARMS, TRAFFICKING IN 1-2 c269 §10E(1)',
#  'FIREFIGHTING, OBSTRUCT c266 §12',
#  'FIREWORKS, STORE IMPROP c148 §40',
#  'FISH/WILDLIFE\x97FISHING VIOLATION 321 CMR §4.07',
#  'FISH/WILDLIFE\x97MASS/NH POND VIOL 321 CMR §4.04',
#  'FOOD STAMP TRAFFICKING +$250 c18 §5L(b)',
#  'FOREIGN CURRENCY, CIRCULATE c267 §21',
#  'FORESTS/PARKS--RULES VIOLATION 304 CMR §12.00',
#  'FORGERY OF COMMONWEALTH NOTE c267 §7',
#  'FRAUDULENT APPROPRIATION OF CORPORATE FUNDS c266 §74',
#  'FURNISH MARIJUANA TO PERSON < 21 YEARS OLD  c94G §13(i)',
#  'GRAND JURY TRANSCRIPT, ABUSE c268 s.13D(a)',
#  'HANG ONTO MV, 3RD OFFENSE c90 §13',
#  'HARASSMENT PREVENTION ORDER, VIOLATE c258E §9',
#  'HARMFUL SUBSTANCE, DISTRIBUTE FOOD WITH c270 §8A',
#  'HAZARDOUS WASTE VIOLATION c21C §5',
#  'HEALTH REGULATION VIOLATION, BOH c111 §31',
#  'HEROIN/MORPHINE/OPIUM, TRAFFICKING IN 100 GRAMS OR MORE, LESS THAN 200 GRAMS c94C',
#  'HEROIN/MORPHINE/OPIUM, TRAFFICKING IN 18 GRAMS OR MORE, LESS THAN 36 GRAMS c94C §32E(c)',
#  'HEROIN/MORPHINE/OPIUM, TRAFFICKING IN 200 GRAMS OR MORE c94C §32E(c)',
#  'HEROIN/MORPHINE/OPIUM, TRAFFICKING IN 36 GRAMS OR MORE, LESS THAN 100 GRAMS c94C §32E(c)',
#  'HOAX DEVICE / SUBSTANCE, POSSESS / TRANSPORT c266 §102A 1/2',
#  'HYPODERMIC, DISTRIB WITHOUT LIC c94C §27(e)',
#  'IGNITION INTERLOCK, OPERATE WITHOUT',
#  'IMPROPER USE OF A CREDIT CARD OVER $250 c266 §37B(b)',
#  'INCENDIARY DEVICE, CHEM/BIO/NUCLEAR WEAPON, POSSESS c266 §102(a)',
#  'INDECENT A&B ON +60/DISABLED c265 §13H',
#  'INSPECTOR, UNCERTIFIED MV c90 §7Y',
#  'INSURANCE AGENT/BROKER, FRAUD BY c175 §170',
#  'INSURANCE CERTIFICATE, ISSUE IMPROPER MV c90 §34B',
#  'INTIMIDATION OF A WITNESS',
#  'KEEPING GAMING APPARATUS c271 §17',
#  'KIDNAPPING & ENDANGER PERSON IN CUSTODY c265 §26A',
#  'LARC. BY CHECK',
#  'LARCENY UNDER $250 BY BOAT CAPTAIN c266 §32 & §30(1)',
#  'LEASE MOTORCYCLES WITHOUT LICENSE c90 §32H',
#  'LEASED/COLLATERAL PROPERTY, BUY/RECEIVE c266 §86',
#  'LIBRARY MATERIALS OVER $250, LARCENY OF c266 §99A',
#  'LIBRARY, DISTURB c272 §41',
#  'LICENSE REVOKED AS HTO, OPERATE MV WITH (CRIMINAL) c90 §23',
#  'LICENSE SUSPENDED FOR OUI, OUI WHILE c90 §23',
#  'LICENSE SUSPENDED, OP MV WITH (CRIMINAL SUBSQ.OFF.) c90 §23',
#  'LIGHTS VIOLATION *, WINDSHIELD WIPERS ON c85',
#  'LIQUOR, PERSON UNDER 21 ATTEMPT PROCURE c138 §34A',
#  'LIQUOR, PERSON UNDER 21 POSSESS, SUBSQ. c138 §34C',
#  'LOTTERY TICKET, ALTER/FORGE/COUNTERFEIT c10 §30',
#  'LOTTERY, AID FOREIGN c271 §15',
#  'MACHINE GUN, POSSESS, LOADED c269 s.10(n)',
#  'MANSLAUGHTER WHILE OUI c265 §13½',
#  'MARIHUANA +1 OZ, POSSESS c94C  §34',
#  'MARIHUANA, POSSESS, SUBSQ.OFF. c94C §34',
#  'MASS PIKE - HEADLIGHT HIGH BEAM VIOLATION *  700 CMR §7.09(22)',
#  'MASS PIKE - MARKED LANES VIOLATION *  700 CMR §7.09(8)',
#  'MASS PIKE - SPEEDING * 700 CMR §7.09(6)(a)',
#  'MASS PIKE - TOO CLOSE *  700 CMR §7.09(15)',
#  'MASS PIKE\x97FALLING DEBRIS * 730 CMR §7.05(5)(f)',
#  'MASS PIKE\x97LIQUOR, UNLAWFULLY TRANSPORT *  730 CMR §7.08(29)',
#  'MASS PIKE\x97PARKING $15 VIOLATION * 730 CMR §7.08(3)&(4)',
#  'MASS PIKE\x97WINDOW OBSTRUCTED * 730 CMR §7.05(5)(c)',
#  'MASSAGE/BATHS, UNLICENSED c140 §51',
#  'MBOAT ID NO. CERTIFICATE, NO c90B §3(a)',
#  'MEDICAL MARIJUANA CARD/CULTIVATION REGIS, FRAUD USE OF FOR PROFIT St. 2012, c.369,',
#  'MEDICAL MARIJUANA CARD/CULTIVATION REGIS, FRAUD USE OF FOR PROFIT St2012 c369 §14',
#  'MEDICINE, UNAUTHORIZED PRACTICE OF c112 §6',
#  'MENTALLY RETARDED, PUBLIC EXPOSURE OF c19B §15(f)',
#  'METHAMPHETAMINE, TRAFFICKING IN  100 GRAMS OR MORE, LESS THAN 200 GRAMS  c94C §32E(b)',
#  'METHAMPHETAMINE, TRAFFICKING IN  36 GRAMS OR MORE, LESS THAN 100 GRAMS  c94C §32E(b)',
#  'METHAMPHETAMINE, TRAFFICKING IN 18 GRAMS OR MORE, LESS THAN 36 GRAMS  c94C §32E(b)',
#  'METHAMPHETAMINE, TRAFFICKING IN 200 GRAMS OR MORE  c94C §32E(b)',
#  'MISCELLANNEOUS MUNIC MOTER VEHICLE ORDINANACE/BYLAW VIOL Everett Ordinance',
#  'MOBILE PHONE, OPERATOR UNDER 18 USE * c90 §8M',
#  'MOTOR VEH HOMICIDE OUI\x97DRUGS & RECKLESS c90 §24G(a)',
#  'MOTOR VEH ODOMETER, TAMPER WITH c266 §141A',
#  'MOTORCYCLE, NOISY * c90 §7U',
#  'MOTORIST CALL BOX, TAMPER WITH c268 §32',
#  'MOTORIZED SCOOTER VIOLATION * c90  §1E',
#  'MUNIC EMPLOYEE, IMPROP COMPENSATION TO c268A §17(b)',
#  'MUNICIPAL/COUNTY OFFCR, EMBEZZLEMENT BY c266 §51',
#  'MV REPAIR SHOP VIOLATIONS c100A §8',
#  'NEGLIGENT OPERATION & INJURY FROM MOBILE PHONE USE c90 §24(2)(a)',
#  'NOTARY RECORDS, DESTROY c222 §10',
#  'NUISANCE REGULATION VIOLATION, HEALTH c111 §122',
#  'NUMBER PLATE, TAKE c266 §139',
#  'OBSCENE MATTER, DISTRIBUTE, 3RD OFF. c272 §29',
#  'OP MV W/O LICENSE',
#  'OPERATING MOTOR VEHICLE UNDER INFLUENCE- 6TH OFFENSE c90 §24',
#  'OPERATING UNLICENSED FAMILY CHILD CARE HOME',
#  'ORGANIZED RETAIL CRIME c266 §30D(b)',
#  'OUI--LIQUOR OR .08%, 6TH OFFENSE c90 §24(1)(a)(1)',
#  'OUI--LIQUOR OR .08%, 7TH OFFENSE c90 §24(1)(a)(1)',
#  'OUI--LIQUOR OR .08%, 8TH OFFENSE c90 §24(1)(a)(1)',
#  'OUI--LIQUOR OR .08%, 9TH OFFENSE c90 §24(1)(a)(1)',
#  'OVERSIZE MV * c90 §19',
#  'PEDDLING DOOR-TO-DOOR VIOLATION c101 §34',
#  'PHOTOGRAPH OF UNSUSPECTING NUDE PERSON, DISSEMINATE c272 §105(c)',
#  'PHOTOGRAPH SEXUAL OR INTIMATE PARTS W/OUT CONSENT c272',
#  'PHOTOGRAPH UNSUSPECTING NUDE PERSON c272 §105(b)',
#  'PLUMBER, UNLICENSED c142 §16',
#  'PLUMBING VIOLATION c142 §16',
#  'POLICE OFFICER, WILLFULLY MISLEADING',
#  'POSSESS LOADED FIREARM/SAWED OFF SHOTGUN/MACHINE GUN c269 §10(n)',
#  'POSSESSION OF MARIHUANA ONE OUNCE OR LESS  c94C §32L',
#  'POSSESSION OF MARIHUANA ONE OUNCE OR LESS < 18 YEARS OLD  c94C §32L',
#  'POSSESSION OF RIFLE C269 §10(h)',
#  'PRISONER, RECEIVE ARTICLE FROM c268 §31',
#  'PUBLIC EMPLOYEE STANDARDS OF CONDUCT VIOL c268A §26',
#  'PUBLIC EMPLOYEE, GIFT TO c268A §3(a)',
#  'PURCHASING VIOLATION, GOVERNMENT c266 §67A',
#  'Photographing, videotaping, surveilling Unsuspecting Nude or Partially Nude Person c272 §104B(b)',
#  'REAL ESTATE APPRAISER, UNLIC c112 §194(A)',
#  'RECEIVE STOLEN PROPERTY +$250, SUBSQ c266',
#  'REGISTER MV IMPROPERLY TO AVOID TAXES/PREMIUMS c90 §3 1/2 (c) (1)',
#  'REGISTER MV IMPROPERLY TO AVOID TAXES/PREMIUMS c90 §3 1/2 (c) (2)',
#  'REGISTRATION, FL SURRENDER ON TRANSFER * c90 §2',
#  'RESIDENT LIST, FALSE INFORMATION FOR c56 §5',
#  'SCHOOL, VANDALIZE c266 §98',
#  'SELF-DEFENSE SPRAY, POSS BY MINOR UNDER FIFTEEN c140 §122D',
#  'SELF-INSURER FAIL NOTIFY OF SUIT c90 §34F',
#  'SEX OFFENDER FAIL TO REGISTER, LEVEL 2 or 3 c6 §178H(c)',
#  'SEX OFFENDER FAIL TO REGISTER, SUBSQ. OFF., LEVEL 2 OR 3  c6',
#  'SEXUALLY DANGEROUS PERSON',
#  'SHOPLIFTING BY ASPORTATION, 3RD AND SUBSEQUENT OFF. c266 §30A',
#  'SHPLFTG BY ASPORT. OF MERCH.',
#  'SNOW PLOW/HITCH, FAIL REMOVE * c90 §19K',
#  'SNOW/REC VEH - DAMAGE PROPERTY, ON * c90B §26(f)',
#  'SNOW/REC VEH - NEGLIGENT/RECKLESS OP c90B §26B(a)',
#  'SNOW/REC VEH - OUI BY +21 - LIQUOR OR .08% c90B §26A(a)',
#  'SNOW/REC VEH - OUI BY - 21 - LIQUOR OR .02% c90B §26A(b)',
#  'SNOW/REC VEH - REFUSE STOP FOR POLICE * c90B §26(c)',
#  'SOIL-REMOVAL BY-LAW VIOLATION c40 §21(17)',
#  'SOLICIT TO COMMIT CRIME PUNISHABLE BY 10 YEARS OR MORE c274 §8',
#  'SOLICIT TO COMMIT CRIME PUNISHABLE BY 5 YEARS OR MORE c274 §8',
#  'SOLICIT TO COMMIT CRIME PUNISHABLE BY IMPRISONMENT FOR LIFE c274 §8',
#  'SOLICIT TO COMMIT CRIME PUNISHABLE BY LESS THAN 5 YEARS c274 §8',
#  'SOLICITATION, FAIL IDENTIFY PAID c68 §35',
#  'SPEEDING IN CONSTRUCTION ZONE',
#  'SPEEDING RATE OF SPEED EXCEEDING POSTED LIMIT  c90 §17',
#  'SPEEDING RATE OF SPEED GREATER THAN WAS REASONABLE AND PROPER  c90 §17',
#  'SPITTING IN PUBLIC PLACE c270 §14',
#  'STALKING, SUBSQ.OFF. c265 §43(c)',
#  'STATE HWAY\x97CLOSED TO TRAVEL, PERSON WHERE c85 §2E',
#  'STATE HWAY\x97GUBERNATORIAL BY-LAW VIOL * c85 §23',
#  'STATE HWAY\x97IMPACT TRAFFIC ON c81 §21',
#  'STATE HWAY\x97SNOW, PILE/PUSH/PLOW c85 §7B',
#  'STATE SANITARY CODE MEDICAL WASTE VIOL c111 §127A',
#  'STATE SANITARY CODE VIOLATION c111 §127A',
#  'STEALING BY CONFINING c265 §21',
#  'STEALING BY PUTTING IN FEAR c265 §21',
#  'STOLEN VALOR, FRAUD REPRESENTATION AS MILITARY OR VETERAN c272 §106(a)(i)',
#  'STOLEN VALOR, FRAUD REPRESENTATION AS RECIPIENT OF MILITARY HONOR c272 §106(a)(ii)',
#  'STRANGULATION OR SUFFOCATION SUBSEQUENT OFFENSE c265 §15D(c)',
#  'STRANGULATION OR SUFFOCATION c265 §15D(b)',
#  'STRANGULATION OR SUFFOCATION, SERIOUS BODILY INJURY c265 §15D(c)',
#  'STRANGULATION OR SUFFOCATION, VIOLATION OF COURT ORDER c265 §15D(c)',
#  'SUPPORT NEEDY DISABLED PERSON, FAIL TO c273 §23',
#  'SUPPORT ORDER, FAIL COMPLY WITH c273 §1(4)',
#  'SUPPORT, ABANDON CHILD WITHOUT c273 §1(1)',
#  'SUPPORT, ABANDON SPOUSE & CHILD WITHOUT c273 §1(1)',
#  'Starting Ignition Interlock MV for another person under a restricted license',
#  'TATTOOING c265 §34',
#  'TAX COLLECTOR, CORRUPT c62C §73(h)',
#  'TAX COLLECTOR, IMPEDE BY FORCE c62C §73(h)',
#  'TAX PREPARER, EMBEZZLEMENT BY c62C §73(f)(5)',
#  'TAX RECORDS/INFO, FAIL PROVIDE c62C §73(c)',
#  'TAXI RECORDKEEPING VIOLATION c159A §10',
#  'TELEPHONE DEVICE, UNLAWFUL c166 §42B',
#  'TELEPHONE FOR GAMING, USE c271 §17A',
#  'TRANSITIONAL ASSISTANCE FUNDS +$100, EMBEZZLE/STEAL/OBTAIN',
#  'TRASH TREATMENT FACILITY, IMPROPER c111 §150A',
#  'TRASH, LITTER FROM MV, SUBSQ.OFF. c270 §16',
#  'TREASURY EMPLOYEE, FRAUD BY c266 §50',
#  'TRICK, OBTAIN PROPERTY UNDER $250 BY c266 §75',
#  'TRUST COMPANY FAIL MAINTAIN RESERVES c172 §31',
#  'UNAUTH USE OF CREDIT CARDS >$1,000 VALUE c140D §27',
#  'UNAUTH USE OF CREDIT CARDS; USE OF GOODS OBTAINED THROUGH  c140D §27',
#  'UNLAWFUL DEACTIVATION OR REMOVAL OF THEFT DETECTION DEVICE c266 §30B(e)',
#  'UNLAWFUL DISTRIBUTION OF THEFT DETECTION DEVICE DEACTIVATOR OR REMOVER c266 §30B(d)',
#  'UNLAWFUL DISTRIBUTION OF THEFT DETECTION SHEILDING DEVICE c266 §30B(a)',
#  'UNLAWFUL POSSESSION OF THEFT DETECTION DEVICE DEACTIVATOR OR REMOVER c266 §30B(c)',
#  'UNLAWFUL POSSESSION OF THEFT DETECTION SHIELDING DEVICE c266 §30B(b)',
#  'UNLICENSED OPERATOR, EMPLOY c90 §12(a)',
#  'UNLICENSED/SUSPENDED OPERATION OF MV, PERMIT, SUBSQ. OFF. c90 §12(b)',
#  'USED CAR SALES, UNLICENSED c140 §68',
#  'UTILITY WIRES, CUT IN DAY c166 §40',
#  'Unlicensed/Suspended operation of mv, permit',
#  'WATER SUPPLY, BATHE IN c111 §171',
#  'WEIGHT CERTIFICATE VIOLATION * c90 §19D',
#  'WEIGHT VIOLATION ON COUNTY WAY * c85 §30',
#  'WEIGHT VIOLATION ON HWAY BRIDGE * c85 §35',
#  'WEIGHT VIOLATION ON MUNICIPAL WAY * c85 §30',
#  'WEIGHT VIOLATION ON STATE HWAY * c85 §30',
#  'WEIGHT VIOLATION WITH IRREDUCIBLE LOAD * c90 §19A & §20',
#  'WETLANDS VIOLATION, INLAND c131 §40A',
#  'WILD ANIMAL IMPORT VIOLATION c131 §19A',
#  'WITHHOLD EVIDENCE FROM OFFICIAL PROCEEDING c268 §13E(b)',
#  'WITNESS ACCEPT/SOLICIT BRIBE c268A §2(d)',
#  'WITNESS FAIL TO APPEAR IN CRIMINAL CASE c233 §5',
#  'WITNESS, CONVEYING SOMETHING OF VALUE TO',
#  'WITNESS, INTIMIDATE c268 §13B(1)',
#  'WITNESS/JUROR/POLICE/COURT OFFICIAL, INTIMIDATE c268 §13B',
#  'YOUTHFUL OFFENDER c119 §54']

# %%
columns = ['Case Number', 'Offense Date', 'Court Location', 'Charge', 'Charge/Crime Type',
          'Disposition Description', 'CMRoffense', 'Chapter', 'Section', 'Paragraph', 'JuvenileC', 
          'years_since_offense', 'sex', 'murder', 'Expungeable']
ms_merged_charges = ms_merged_charges[columns]

# %%
ms_merged_charges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392605 entries, 0 to 392604
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Case Number              392605 non-null  object
#  1   Offense Date             392578 non-null  object
#  2   Court Location           392605 non-null  object
#  3   Charge                   392605 non-null  object
#  4   Charge/Crime Type        392605 non-null  object
#  5   Disposition Description  392605 non-null  object
#  6   CMRoffense               392605 non-null  bool
#  7   Chapter                  392605 non-null  object
#  8   Section                  389306 non-null  object
#  9   Paragraph                309266 non-null  object
#  10  JuvenileC                392605 non-null  bool
#  11  years_since_offense      392605 non-null  int32
#  12  sex                      360749 non-null  float64
#  13  murder                   360336 non-null  float64
#  14  Expungeable              392222 non-null  object
# dtypes: bool(2), float64(2), int32(1), object(10)
# memory usage: 41.2+ MB

# %%
ms_merged_charges.to_csv('../../data/processed/merged_ms.csv', index=False)
