# %% [markdown]
# # Clean Slate: Exploring dispositions in the datasets
# > Prepared by [Laura Feeney](https://github.com/laurafeeney) for Code for Boston's [Clean Slate project](https://github.com/codeforboston/clean-slate).
#
# ## Purpose
# Exploring duplicate charges, dispositions, and moves from one court to another.
#
# -----

# %% [markdown]
# ### Step 0
# Import data, programs, etc.
#
# -----

# %%
import pandas as pd
pd.set_option("display.max_rows", 200)
import numpy as np
import regex as re
import glob, os
import datetime 
from datetime import date

# %%
# processed individual-level data from NW district with expungability.

suff = pd.read_csv('../../data/processed/merged_suff.csv', encoding='cp1252',
                    dtype={'Analysis notes':str, 'extra_criteria':str, 'Expungeable': str}) 
suff.info()

nw = pd.read_csv('../../data/processed/merged_nw.csv', encoding='cp1252',
                    dtype={'Analysis notes':str, 'extra_criteria':str, 'Expungeable': str}) 
nw.info()

ms = pd.read_csv('../../data/processed/merged_ms.csv', encoding='cp1252',
                    dtype={'Analysis notes':str, 'extra_criteria':str, 'Expungeable': str}, low_memory=False) 
ms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303270 entries, 0 to 303269
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Person ID                       303270 non-null  object
#  1   Court                           303270 non-null  object
#  2   Offense Date                    300877 non-null  object
#  3   Filed                           303270 non-null  object
#  4   Status                          303270 non-null  object
#  5   Count                           303270 non-null  int64
#  6   Charge                          303270 non-null  object
#  7   Type Crime                      303270 non-null  object
#  8   Code Ucc Ctgry                  262955 non-null  object
#  9   Disposition                     251710 non-null  object
#  10  Description Disposition Reason  212684 non-null  object
#  11  Dispo Date                      251300 non-null  object
#  12  CMRoffense                      303270 non-null  object
#  13  Chapter                         297886 non-null  object
#  14  Section                         297884 non-null  object
#  15  sex                             303270 non-null  int64
#  16  murder                          303270 non-null  int64
#  17  extra_criteria                  12878 non-null   object
#  18  Reason not expungeable          31572 non-null   object
#  19  Analysis notes                  3944 non-null    object
#  20  Expungeable                     303270 non-null  object
# dtypes: int64(3), object(18)
# memory usage: 48.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75725 entries, 0 to 75724
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Person ID               75725 non-null  object
#  1   Court                   75725 non-null  object
#  2   Offense Date            74915 non-null  object
#  3   Age at Offense          74783 non-null  float64
#  4   Filed                   75725 non-null  object
#  5   Status                  75725 non-null  object
#  6   Count                   75725 non-null  int64
#  7   Charge                  75725 non-null  object
#  8   Disposition             72259 non-null  object
#  9   Dispo Date              71881 non-null  object
#  10  CMRoffense              75725 non-null  object
#  11  Chapter                 72457 non-null  object
#  12  Section                 72588 non-null  object
#  13  sex                     75725 non-null  int64
#  14  murder                  75725 non-null  int64
#  15  extra_criteria          2540 non-null   object
#  16  Reason not expungeable  7457 non-null   object
#  17  Analysis notes          2 non-null      object
#  18  Expungeable             75724 non-null  object
# dtypes: float64(1), int64(3), object(15)
# memory usage: 11.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392605 entries, 0 to 392604
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Case Number              392605 non-null  object
#  1   Offense Date             392578 non-null  object
#  2   Date of Filing           392605 non-null  object
#  3   Court Location           392605 non-null  object
#  4   Charge/Crime Code        392605 non-null  object
#  5   Charge                   392605 non-null  object
#  6   Charge/Crime Type        392605 non-null  object
#  7   Disposition Code         392605 non-null  object
#  8   Disposition Description  392605 non-null  object
#  9   Disposition Date         392605 non-null  object
#  10  CMRoffense               392605 non-null  object
#  11  Chapter                  392605 non-null  object
#  12  Section                  389306 non-null  object
#  13  Paragraph                309266 non-null  object
#  14  Charge_noA               392605 non-null  object
#  15  Charge_alnum             392605 non-null  object
#  16  Charge_alnum2            392605 non-null  object
#  17  JuvenileC                392605 non-null  object
#  18  years_since_offense      392578 non-null  float64
#  19  sex                      360336 non-null  float64
#  20  murder                   360336 non-null  float64
#  21  extra_criteria           10390 non-null   object
#  22  Analysis notes           10 non-null      object
#  23  unmatched                392605 non-null  bool
#  24  Source                   1440 non-null    object
#  25  Further Review           671 non-null     object
#  26  Row or Code from MCL     30928 non-null   object
#  27  Expungeable              392222 non-null  object
#  28  Reason not expungeable   61574 non-null   object
# dtypes: bool(1), float64(3), object(25)
# memory usage: 84.2+ MB

# %%
ms.head()
# Out:
#     Case Number Offense Date Date of Filing Court Location Charge/Crime Code  \
# 0  14-01-479818   2013-12-30       1/2/2014            SOM           90/23/D
# 1  14-01-479826   2013-12-29       1/2/2014            LOW           90/23/D
# 2  14-01-479854   2013-12-31       1/2/2014            SOM           90/23/D
# 3  14-01-479887   2013-12-28       1/6/2014            AYE           90/23/D
# 4  14-01-479888   2013-05-19       1/6/2014            CON           90/23/D
#
#                                    Charge  \
# 0  LICENSE SUSPENDED, OP MV WITH c90 Â§23
# 1  LICENSE SUSPENDED, OP MV WITH c90 Â§23
# 2  LICENSE SUSPENDED, OP MV WITH c90 Â§23
# 3  LICENSE SUSPENDED, OP MV WITH c90 Â§23
# 4  LICENSE SUSPENDED, OP MV WITH c90 Â§23
#
#                            Charge/Crime Type Disposition Code  \
# 0  Drugs/Distribution/Possession with Intent              GLF
# 1                           Drugs/Possession              NOP
# 2                        Motor Vehicle Other              DWO
# 3                        Motor Vehicle Other              DWO
# 4                        Motor Vehicle Other              DIF
#
#     Disposition Description Disposition Date  ...  sex murder extra_criteria  \
# 0              GUILTY FILED         6/2/2014  ...  0.0    0.0            NaN
# 1            NOLLE PROSEQUI       11/13/2014  ...  0.0    0.0            NaN
# 2  DISMISSED W/O  PREJUDICE        1/27/2014  ...  0.0    0.0            NaN
# 3  DISMISSED W/O  PREJUDICE        1/24/2014  ...  0.0    0.0            NaN
# 4        DISMISSED BY FINES         4/9/2014  ...  0.0    0.0            NaN
#
#   Analysis notes unmatched Source Further Review Row or Code from MCL  \
# 0            NaN     False    NaN            NaN                  NaN
# 1            NaN     False    NaN            NaN                  NaN
# 2            NaN     False    NaN            NaN                  NaN
# 3            NaN     False    NaN            NaN                  NaN
# 4            NaN     False    NaN            NaN                  NaN
#
#    Expungeable  Reason not expungeable
# 0          Yes                     NaN
# 1          Yes                     NaN
# 2          Yes                     NaN
# 3          Yes                     NaN
# 4          Yes                     NaN
#
# [5 rows x 29 columns]

# %%
print("Suffolk")
#drop CMR offenses, remaining unique people
suff = suff.loc[suff['CMRoffense']=='no'].copy()
print(suff['Person ID'].nunique())
total_people_suff = suff['Person ID'].nunique()

print("NW")
#drop CMR offenses, remaining unique people
nw = nw.loc[nw['CMRoffense']=='no'].copy()
print(nw['Person ID'].nunique())

#drop people >21 in NW
nw=nw.loc[nw['Age at Offense']<21].copy()
print(nw['Person ID'].nunique())
total_people_nw = nw['Person ID'].nunique()

print("Middlesex - no person ID, only case numbers")
#drop CMR offenses, remaining unique people
ms = ms.loc[ms['CMRoffense']=='no'].copy()
print(ms['Case Number'].nunique())

#drop people not in Juvenile court in ms
ms = ms.loc[ms['JuvenileC']=="yes"].copy()
print(ms['Case Number'].nunique())
total_people_ms = ms['Case Number'].nunique()
# Out:
# Suffolk
# 90719
# NW
# 19686
# 2854
# Middlesex - no person ID, only case numbers
# 163727
# 5816

# %%
# In Suffolk, there is only one juvenile court is listed, and it does not appear on this list. 
# https://www.suffolkdistrictattorney.com/about-the-office/contact-directions
# "Some of these courts have juvenile sessions for offenders under the age of 18; courts without a juvenile 
# session send their cases to the Boston Juvenile Court downtown."

print("Suffolk DA courts \n", suff['Court'].value_counts())
print("\n")
print("Northwestern DA courts \n", nw['Court'].value_counts())
print("\n")
print("Middlesex DA courts \n", ms['Court Location'].value_counts())
# Out:
# Suffolk DA courts
#  BMC     66433
# DOR     65212
# ROX     44288
# CHE     35929
# WROX    23391
# SUP     18585
# EBOS    13853
# SBO     13571
# BRI     11710
# CHA      7853
# Name: Court, dtype: int64
#
#
# Northwestern DA courts
#  Belchertown District Court    3275
# Greenfield District Court     1634
# Northampton District Court    1288
# Hadley Juvenile Court         1158
# Orange District Court          799
# Greenfield Juvenile Court      616
# Orange Juvenile Court          401
# Belchertown Juvenile Court     367
# Hampshire Superior Court       178
# Franklin Superior Court         87
# Name: Court, dtype: int64
#
#
# Middlesex DA courts
#  LOWJU    6577
# CAMJU    3392
# FRAJU    3079
# WALJU    1232
# Name: Court Location, dtype: int64

# %%
print("Suffolk - Dispositions \n")
print(suff['Disposition'].loc[suff['Expungeable']=="Yes"].value_counts(dropna=False))

print("Suffolk - % by Disposition \n")
print(suff['Disposition'].loc[suff['Expungeable']=="Yes"].value_counts(normalize=True, dropna=False)*100, "\n")
# Out:
# Suffolk - Dispositions
#
# Dismissed                   111818
# Plea                         44568
# NaN                          36160
# Continued w/o Finding         8526
# Nole Prosequi                 6169
# Pre Trial Probation           3422
# Verdict - Jury Trial          1814
# Verdict - Bench Trial         1730
# Convert to Civil               681
# Filed w/o Change of Plea       276
# General Continuance             91
# Diversion                       74
# No True Bill                    28
# Bound Over                       9
# Pending                          8
# Name: Disposition, dtype: int64
# Suffolk - % by Disposition
#
# Dismissed                   51.918059
# Plea                        20.693306
# NaN                         16.789399
# Continued w/o Finding        3.958695
# Nole Prosequi                2.864320
# Pre Trial Probation          1.588864
# Verdict - Jury Trial         0.842256
# Verdict - Bench Trial        0.803254
# Convert to Civil             0.316194
# Filed w/o Change of Plea     0.128149
# General Continuance          0.042252
# Diversion                    0.034359
# No True Bill                 0.013001
# Bound Over                   0.004179
# Pending                      0.003714
# Name: Disposition, dtype: float64

# %%
print("NW - Dispositions \n")
print(nw['Disposition'].loc[nw['Expungeable']=="Yes"].value_counts(dropna=False))

print("NW - % by Disposition \n")
print(nw['Disposition'].loc[nw['Expungeable']=="Yes"].value_counts(normalize=True, dropna=False)*100, "\n")
# Out:
# NW - Dispositions
#
# Dismissed at Request of Comm         1442
# Continued w/o Finding                1237
# c276s87 finding                      1000
# Nolle Prosequi                        845
# Not Responsible                       762
# Responsible                           512
# Guilty                                330
# Dismissed                             275
# Dismissed on Payment                  239
# Dismissed Prior to Arraignment        230
# NaN                                   224
# Responsible Filed                      84
# Delinquent                             79
# DYS Committed                          22
# Guilty Filed                           21
# Dismissed by Court                     18
# Charge Handled as a Civil Charge       17
# Accord/Satisfaction                    13
# Delinquent Filed                       12
# Found Incompetent                       8
# Case Transferred                        5
# Dismissed prior to complaint            5
# CLOSED-NO CHARGES                       4
# Guilty on Lesser Included Offense       2
# Valor Act Dispo                         2
# Agreed Plea                             2
# Youthful Offender                       1
# Unagreed Plea                           1
# DA's Complaint                          1
# Not Guilty                              1
# Name: Disposition, dtype: int64
# NW - % by Disposition
#
# Dismissed at Request of Comm         19.502299
# Continued w/o Finding                16.729781
# c276s87 finding                      13.524479
# Nolle Prosequi                       11.428185
# Not Responsible                      10.305653
# Responsible                           6.924533
# Guilty                                4.463078
# Dismissed                             3.719232
# Dismissed on Payment                  3.232351
# Dismissed Prior to Arraignment        3.110630
# NaN                                   3.029483
# Responsible Filed                     1.136056
# Delinquent                            1.068434
# DYS Committed                         0.297539
# Guilty Filed                          0.284014
# Dismissed by Court                    0.243441
# Charge Handled as a Civil Charge      0.229916
# Accord/Satisfaction                   0.175818
# Delinquent Filed                      0.162294
# Found Incompetent                     0.108196
# Case Transferred                      0.067622
# Dismissed prior to complaint          0.067622
# CLOSED-NO CHARGES                     0.054098
# Guilty on Lesser Included Offense     0.027049
# Valor Act Dispo                       0.027049
# Agreed Plea                           0.027049
# Youthful Offender                     0.013524
# Unagreed Plea                         0.013524
# DA's Complaint                        0.013524
# Not Guilty                            0.013524
# Name: Disposition, dtype: float64

# %%
print("Middlesex - Dispositions \n")
print(ms['Disposition Description'].loc[ms['Expungeable']=="Yes"].value_counts(dropna=False))

print("Middlesex - % by Disposition \n")
print(ms['Disposition Description'].loc[ms['Expungeable']=="Yes"].value_counts(normalize=True, dropna=False)*100, "\n")
# Out:
# Middlesex - Dispositions
#
# DISMISSED W/O  PREJUDICE                              2769
# PRE-TRIAL PROBATION                                   2558
# CONTINUED W/O FINDING                                 1430
# DISMISSED PRIOR TO ARRAIGNMENT                         549
# DELINQUENT CHANGE OF PLEA                              477
# NOT RESPONSIBLE                                        297
# DISMISSED BY COURT (PRIOR TO ARRAIGNMENT)              255
# NOLLE PROSEQUI                                         156
# DISMISSED W/O PREJUDICE LACK OF PROSECUTION            150
# GUILTY CHANGE OF PLEA                                  143
# DISMISSED BY FINES                                     135
# RESPONSIBLE                                            132
# DISMISSED OUTRIGHT AT REQUEST OF CW (POST-ARR)         127
# GENERAL CONTINUANCE                                    113
# DISMISSED ON COURT COSTS                               107
# DISMISSED OUTRIGHT AT REQUEST OF CW (PRIOR TO ARR)      50
# DELINQUENT BENCH TRIAL                                  37
# DISMISSED BY COURT (POST-ARRAIGNMENT)                   36
# GUILTY FILED                                            35
# NOT DELINQUENT BENCH TRIAL                              26
# FILED WITHOUT CHANGE OF PLEA                            25
# DELINQUENT JURY TRIAL                                   25
# NOT DELINQUENT JURY TRIAL                               22
# MOTION TO DISMISS ALLOWED                               21
# NOT GUILTY BENCH TRIAL                                  16
# NOT GUILTY JURY TRIAL                                   16
# GUILTY FINES                                            12
# DISMISSED ON COMMUNITY SERVICE                          11
# NOT DELINQUENT - DIRECTED VERDICT/REQUIRED FINDING       8
# GUILTY JURY TRIAL                                        6
# TRANSFERRED ESSEX COUNTY                                 5
# REMANDED CLERKS HEARING                                  5
# CONTINUED W/O FINDING LESSER OFFENSE                     4
# DISMISSED PURSUANT TO ACCORD AND SATISFACTION            4
# DISMISSED WITH PREJUDICE LACK OF PROSECUTION             4
# DISMISSED ON RESTITUTION                                 3
# DIVERSION PASS                                           3
# NOT GUILTY - DIRECTED VERDICT/REQUIRED FINDING           2
# MOTION TO SUPPRESS - ALLOWED                             2
# Name: Disposition Description, dtype: int64
# Middlesex - % by Disposition
#
# DISMISSED W/O  PREJUDICE                              28.324468
# PRE-TRIAL PROBATION                                   26.166121
# CONTINUED W/O FINDING                                 14.627660
# DISMISSED PRIOR TO ARRAIGNMENT                         5.615794
# DELINQUENT CHANGE OF PLEA                              4.879296
# NOT RESPONSIBLE                                        3.038052
# DISMISSED BY COURT (PRIOR TO ARRAIGNMENT)              2.608429
# NOLLE PROSEQUI                                         1.595745
# DISMISSED W/O PREJUDICE LACK OF PROSECUTION            1.534370
# GUILTY CHANGE OF PLEA                                  1.462766
# DISMISSED BY FINES                                     1.380933
# RESPONSIBLE                                            1.350245
# DISMISSED OUTRIGHT AT REQUEST OF CW (POST-ARR)         1.299100
# GENERAL CONTINUANCE                                    1.155892
# DISMISSED ON COURT COSTS                               1.094517
# DISMISSED OUTRIGHT AT REQUEST OF CW (PRIOR TO ARR)     0.511457
# DELINQUENT BENCH TRIAL                                 0.378478
# DISMISSED BY COURT (POST-ARRAIGNMENT)                  0.368249
# GUILTY FILED                                           0.358020
# NOT DELINQUENT BENCH TRIAL                             0.265957
# FILED WITHOUT CHANGE OF PLEA                           0.255728
# DELINQUENT JURY TRIAL                                  0.255728
# NOT DELINQUENT JURY TRIAL                              0.225041
# MOTION TO DISMISS ALLOWED                              0.214812
# NOT GUILTY BENCH TRIAL                                 0.163666
# NOT GUILTY JURY TRIAL                                  0.163666
# GUILTY FINES                                           0.122750
# DISMISSED ON COMMUNITY SERVICE                         0.112520
# NOT DELINQUENT - DIRECTED VERDICT/REQUIRED FINDING     0.081833
# GUILTY JURY TRIAL                                      0.061375
# TRANSFERRED ESSEX COUNTY                               0.051146
# REMANDED CLERKS HEARING                                0.051146
# CONTINUED W/O FINDING LESSER OFFENSE                   0.040917
# DISMISSED PURSUANT TO ACCORD AND SATISFACTION          0.040917
# DISMISSED WITH PREJUDICE LACK OF PROSECUTION           0.040917
# DISMISSED ON RESTITUTION                               0.030687
# DIVERSION PASS                                         0.030687
# NOT GUILTY - DIRECTED VERDICT/REQUIRED FINDING         0.020458
# MOTION TO SUPPRESS - ALLOWED                           0.020458
# Name: Disposition Description, dtype: float64
