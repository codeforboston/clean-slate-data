# %%
import pandas as pd
import os

# %%
# get all the files in this directory
datadir = os.listdir()
datadir
# Out:
# ['prosecution_categories',
#  'crime_categories',
#  '.ipynb_checkpoints',
#  'README_processed.md',
#  'Data Overview.ipynb',
#  'README.md',
#  'ma_court_data',
#  'README_cleaned.md',
#  'README_raw.md',
#  'fbi_crime_data']

# %%
print("total files in data directory:", len(datadir) )
# Out:
# total files in data directory: 10

# %%
#most relevant data are in the ma_court_data folder where, specifically the merged files
os.listdir("ma_court_data")
# Out:
# ['merged_suff.csv', 'merged_nw.csv', 'nw.csv', 'suff.csv', 'merged_ms.csv']

# %%
merged_suff = pd.read_csv("ma_court_data/merged_suff.csv")
merged_suff.head()
# merged_suff.shape
# Out:
#   Person ID Court Offense Date       Filed Status  Count  \
# 0      SF-0   SUP   2015-11-04  2016-01-01     CL      1
# 1      SF-0   SUP   2015-11-04  2016-01-01     CL      2
# 2      SF-0   SUP   2015-11-04  2016-01-01     CL      3
# 3      SF-0   SUP   2015-11-04  2016-01-01     CL      4
# 4      SF-1   SUP   2014-10-23  2016-01-01     CL      1
#
#                                               Charge Type Crime  \
# 0  DRUG, DISTRIBUTE CLASS A, SUBSQ.OFF. c94C Ã‚Â§...         DR
# 1    COCAINE, DISTRIBUTE, SUBSQ.OFF. c94C Ã‚Â§32A(d)         DR
# 2  DRUG, POSSESS TO DISTRIB CLASS A, SUBSQ. c94C ...         DR
# 3  POSSESS TO DISTRIBUTE COCAINE, SUBSEQUENT. c94...         DR
# 4                 A&B ON +60/DISABLED c265 Ã‚Â§13K/F         AS
#
#   Code Ucc Ctgry           Disposition  ...  Dispo Date CMRoffense Chapter  \
# 0              F                  Plea  ...  2017-01-31         no     94C
# 1              F                  Plea  ...  2017-01-31         no     94C
# ...

# %%
merged_nw = pd.read_csv("ma_court_data/merged_nw.csv")
merged_nw.head()
# merged_nw.shape
# Out:
# /home/linna/Apps/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Person ID                    Court Offense Date  Age at Offense       Filed  \
# 0      NW-0  Franklin Superior Court   2011-09-13            21.0  2014-10-28
# 1      NW-0  Franklin Superior Court   2011-09-13            21.0  2014-10-28
# 2      NW-0  Franklin Superior Court   2011-09-13            21.0  2014-10-28
# 3      NW-0  Franklin Superior Court   2011-09-13            21.0  2014-10-28
# 4      NW-0  Franklin Superior Court   2011-09-13            21.0  2014-10-28
#
#    Status  Count                              Charge Disposition  Dispo Date  \
# 0  Closed      1       ASSAULT TO MURDER c265 Ã‚Â§15  Not Guilty  2016-03-30
# 1  Closed      2       ASSAULT TO MURDER c265 Ã‚Â§15  Not Guilty  2016-03-30
# ...
